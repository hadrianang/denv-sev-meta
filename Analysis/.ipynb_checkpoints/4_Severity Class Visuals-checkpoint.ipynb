# %% [markdown]
# # 4. Severity Class Visuals
# The goal of this notebook is to generate visuals for a single severity class system (e.g. 1997-type). We assume that the model has already been fitted and heterogeneity values computed prior to running the code in this notebook. This notebook has to be run thrice, once for each of the severity classification systems in the study. See "5_Group Visuals.ipynb" for the visuals that combine results across all three analyses.

# %%
library(tidyverse)
library(ggplot2)
library(rstan)
library(Hmisc)
library(forestplot)
theme_set(theme_bw())
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.3.3"
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: StanHeaders
#
#
# rstan version 2.32.5 (Stan version 2.32.2)
#
#
# For execution on a local, multicore CPU with excess RAM we recommend calling
# options(mc.cores = parallel::detectCores()).
# To avoid recompilation of unchanged Stan programs, we recommend calling
# rstan_options(auto_write = TRUE)
# For within-chain threading using `reduce_sum()` or `map_rect()` Stan functions,
# change `threads_per_chain` option:
# rstan_options(threads_per_chain = 1)
#
#
# Do not specify '-march=native' in 'LOCAL_CPPFLAGS' or a Makevars file
#
#
# Attaching package: 'rstan'
#
#
# The following object is masked from 'package:tidyr':
#
#     extract
#
#
#
# Attaching package: 'Hmisc'
#
#
# The following objects are masked from 'package:dplyr':
#
#     src, summarize
#
#
# The following objects are masked from 'package:base':
#
#     format.pval, units
#
#
# Warning message:
# "package 'forestplot' was built under R version 4.3.3"
# Loading required package: grid
#
# Loading required package: checkmate
#
# Loading required package: abind

# %%
inv_logit = plogis
logit = qlogis

save_plot = function(curr_plot, filepath, width, height, units, res, type = "png"){
    if(type == "png"){
        png(filepath, width = width, height = height, units = units, res = res)
    }else if(type == "eps"){
        postscript(filepath, width = width, height = height, units = units, res = res)
    }else{
        pdf(filepath, width = width, height = height, units = units, res = res)
    }
    print(curr_plot)
    dev.off()
}

save_plot_all_formats = function(curr_plot, dir_path, filename, width, height, units, res){
    
}

# %%
base_dir = getwd()
io_set = "Main Results"

model_input_dir = file.path(base_dir, "Processed Data", io_set)
model_output_dir = file.path(base_dir, "Model Output", io_set)
het_dir = file.path(base_dir, "Heterogeneity Estimates", io_set)

# %%
#Code should be run for each of the severity classifications
#sev_class_type = "1997type"
#sev_class_type = "2009type"
sev_class_type = "hospitalisation"
visuals_output_dir = file.path(base_dir, "Visuals Output", io_set, sev_class_type)



subgroup_forests_dir = file.path(visuals_output_dir, "ScenarioForests")

input_data = file.path(model_input_dir, paste0("data_", sev_class_type, ".rds")) %>% readRDS
model_results = file.path(model_output_dir, paste0("Results_LogisticRegression_mean=0_sd=2_sd_mean=0.5_sdsd=2_", sev_class_type, ".rds")) %>% readRDS
het_results = file.path(het_dir, paste0("I2_Estimates_", sev_class_type, ".rds")) %>% readRDS

# %%
save_output = TRUE

# %% [markdown]
# # Model Fit Visual
# First, we generate a visual showing how the model fits to the data.

# %%
#The theta values can be compared to the values in the input outcome_df
outcome_df = input_data$outcome_df

#First, we get our data and compute the 95% binomial confidence intervals
fit_vis_df = outcome_df %>% select(CovidenceID, Scenario, N, Severe) %>%
            cbind(binconf(outcome_df$Severe, outcome_df$N, method = "exact", return.df = TRUE)) %>% 
            mutate(Type = "DATA") %>% select(-c(N, Severe))

#We retrieve the model estimates, which are the values of theta from the model results
theta_est = summary(model_results, pars = "theta")$summary %>% data.frame

fit_vals = theta_est %>% select(mean, X2.5., X97.5.) %>% 
            rename(PointEst = mean, Lower = X2.5., Upper = X97.5.) %>% 
            cbind(fit_vis_df %>% select(CovidenceID, Scenario)) %>% 
            mutate(Type = "MODEL")

fit_vis_df = rbind(fit_vis_df, fit_vals)

#We rename the single study with no author for ease of visaulisation (this was a WHO bulletin)
fit_vis_df = fit_vis_df %>% mutate(CovidenceID = ifelse(CovidenceID == "#9", "#9 - WHO 1987", CovidenceID))
fit_vis_df
# Out:
#           CovidenceID              Scenario               PointEst
# X         #66490 - Fiora 2024      Americas-Unknown-DENV1 0.00000000
# X.1       #1923 - Hanna 1998       Asia-Unknown-DENV2     0.00000000
# X.2       #1924 - Hanna 2001       Asia-Unknown-DENV3     0.20281124
# X.3       #66352 - Rahim 2023      Asia-Unknown-DENV1     0.45000000
# X.4       #66352 - Rahim 2023      Asia-Unknown-DENV2     0.55769231
# X.5       #66352 - Rahim 2023      Asia-Unknown-DENV3     0.34987593
# X.6       #2880 - Ly 2022          Americas-Unknown-DENV1 0.00000000
# X.7       #2880 - Ly 2022          Americas-Unknown-DENV2 0.15384615
# X.8       #661 - Burattini 2016    Americas-Unknown-DENV1 0.11549755
# X.9       #661 - Burattini 2016    Americas-Unknown-DENV2 0.25516102
# X.10      #661 - Burattini 2016    Americas-Unknown-DENV3 0.16837009
# X.11      #661 - Burattini 2016    Americas-Unknown-DENV4 0.08549472
# X.12      #66248 - Estofolete 2023 Americas-Unknown-DENV1 0.10672854
# X.13      #66248 - Estofolete 2023 Americas-Unknown-DENV2 0.24615385
# X.14      #365 - Aubry 2019        Asia-Unknown-DENV1     0.05777778
# X.15      #365 - Aubry 2019        Asia-Unknown-DENV2     0.07547170
# X.16      #1695 - GomezDantes 1988 Americas-Unknown-DENV1 0.00000000
# X.17      #66187 - AlBalushi 2023  Asia-Unknown-DENV2     0.55029586
# X.18      #66690 - Burgos 2025     Americas-Unknown-DENV1 0.03092784
# X.19      #66690 - Burgos 2025     Americas-Unknown-DENV2 0.02212389
# X.20      #735 - Capeding 2010     Asia-Primary-DENV3     0.61111111
# X.21      #4191 - Santiago 2019    Americas-Unknown-DENV2 0.50641026
# X.22      #4191 - Santiago 2019    Americas-Unknown-DENV3 0.43846154
# X.23      #66614 - Rodriguez 2024  Americas-Unknown-DENV1 0.37273130
# X.24      #66614 - Rodriguez 2024  Americas-Unknown-DENV2 0.50240385
# X.25      #66614 - Rodriguez 2024  Americas-Unknown-DENV3 0.60879420
# X.26      #66614 - Rodriguez 2024  Americas-Unknown-DENV4 0.34155895
# X.27      #4095 - Rouers 2021      Asia-Primary-DENV1     0.14285714
# X.28      #4095 - Rouers 2021      Asia-Primary-DENV2     0.10000000
# X.29      #4095 - Rouers 2021      Asia-Secondary-DENV1   0.42857143
# ⋮         ⋮                        ⋮                      ⋮
# theta[19] #66690 - Burgos 2025     Americas-Unknown-DENV1 0.03196993
# theta[20] #66690 - Burgos 2025     Americas-Unknown-DENV2 0.02735293
# theta[21] #735 - Capeding 2010     Asia-Primary-DENV3     0.59956265
# theta[22] #4191 - Santiago 2019    Americas-Unknown-DENV2 0.50412282
# theta[23] #4191 - Santiago 2019    Americas-Unknown-DENV3 0.43690317
# theta[24] #66614 - Rodriguez 2024  Americas-Unknown-DENV1 0.37268042
# theta[25] #66614 - Rodriguez 2024  Americas-Unknown-DENV2 0.50223250
# theta[26] #66614 - Rodriguez 2024  Americas-Unknown-DENV3 0.60836140
# theta[27] #66614 - Rodriguez 2024  Americas-Unknown-DENV4 0.34142260
# theta[28] #4095 - Rouers 2021      Asia-Primary-DENV1     0.11896712
# theta[29] #4095 - Rouers 2021      Asia-Primary-DENV2     0.08886347
# theta[30] #4095 - Rouers 2021      Asia-Secondary-DENV1   0.36193328
# theta[31] #4095 - Rouers 2021      Asia-Secondary-DENV2   0.41617877
# theta[32] #5345 - Yung 2015        Asia-Unknown-DENV1     0.63201297
# theta[33] #5345 - Yung 2015        Asia-Unknown-DENV2     0.41725714
# theta[34] #5345 - Yung 2015        Asia-Unknown-DENV3     0.45108807
# theta[35] #4127 - Sabchareon 2012  Asia-Unknown-DENV1     0.51652351
# theta[36] #4127 - Sabchareon 2012  Asia-Unknown-DENV2     0.40645588
# theta[37] #4127 - Sabchareon 2012  Asia-Unknown-DENV3     0.49187887
# theta[38] #4127 - Sabchareon 2012  Asia-Unknown-DENV4     0.52908321
# theta[39] #4158 - Salje 2018       Asia-Unknown-DENV1     0.24983830
# theta[40] #4158 - Salje 2018       Asia-Unknown-DENV2     0.17586337
# theta[41] #4158 - Salje 2018       Asia-Unknown-DENV3     0.32470646
# theta[42] #4158 - Salje 2018       Asia-Unknown-DENV4     0.10440421
# theta[43] #5457 - Mammen 2008      Asia-Unknown-DENV4     0.17719467
# theta[44] #1385 - Duyen 2011       Asia-Primary-DENV1     0.05254768
# theta[45] #1385 - Duyen 2011       Asia-Primary-DENV2     0.04391397
# theta[46] #1385 - Duyen 2011       Asia-Primary-DENV3     0.02888216
# theta[47] #1385 - Duyen 2011       Asia-Secondary-DENV1   0.03573660
# theta[48] #1385 - Duyen 2011       Asia-Secondary-DENV2   0.06272424
#           Lower        Upper      Type
# X         0.000000000  0.13718517 DATA
# X.1       0.000000000  0.45925813 DATA
# X.2       0.168344742  0.24084989 DATA
# X.3       0.292588350  0.61509321 DATA
# X.4       0.413275561  0.69530438 DATA
# X.5       0.303323959  0.39865130 DATA
# X.6       0.000000000  0.24705264 DATA
# X.7       0.019206672  0.45447106 DATA
# X.8       0.107599148  0.12376384 DATA
# X.9       0.230813346  0.28070348 DATA
# X.10      0.151624546  0.18616893 DATA
# X.11      0.075919560  0.09585430 DATA
# X.12      0.079204594  0.13978759 DATA
# X.13      0.147723055  0.36872858 DATA
# X.14      0.031119489  0.09677533 DATA
# X.15      0.033145811  0.14330113 DATA
# X.16      0.000000000  0.08041994 DATA
# X.17      0.472020769  0.62677574 DATA
# X.18      0.011432886  0.06609829 DATA
# X.19      0.007221688  0.05087177 DATA
# X.20      0.434638047  0.76857560 DATA
# X.21      0.449499724  0.56319795 DATA
# X.22      0.377233052  0.50110903 DATA
# X.23      0.365674891  0.37982868 DATA
# X.24      0.478093600  0.52670560 DATA
# X.25      0.588069027  0.62922989 DATA
# X.26      0.328547006  0.35475225 DATA
# X.27      0.017794515  0.42812916 DATA
# X.28      0.002528579  0.44501612 DATA
# X.29      0.098988278  0.81594843 DATA
# ⋮         ⋮            ⋮          ⋮
# theta[19] 1.258688e-02 0.05969167 MODEL
# theta[20] 1.031497e-02 0.05240207 MODEL
# theta[21] 4.371328e-01 0.75226565 MODEL
# theta[22] 4.489453e-01 0.55854807 MODEL
# theta[23] 3.780299e-01 0.49825800 MODEL
# theta[24] 3.655998e-01 0.37977229 MODEL
# theta[25] 4.781912e-01 0.52631417 MODEL
# theta[26] 5.880266e-01 0.62869403 MODEL
# theta[27] 3.283820e-01 0.35452526 MODEL
# theta[28] 2.234688e-02 0.31484489 MODEL
# theta[29] 5.924014e-03 0.29377925 MODEL
# theta[30] 7.755558e-02 0.71626809 MODEL
# theta[31] 1.767611e-01 0.67925689 MODEL
# theta[32] 5.375645e-01 0.72386092 MODEL
# theta[33] 3.590344e-01 0.47679596 MODEL
# theta[34] 3.511318e-01 0.55506525 MODEL
# theta[35] 4.343528e-01 0.59753954 MODEL
# theta[36] 3.135967e-01 0.50245365 MODEL
# theta[37] 3.778520e-01 0.60855319 MODEL
# theta[38] 3.312155e-01 0.71723058 MODEL
# theta[39] 1.333390e-01 0.39113375 MODEL
# theta[40] 1.091302e-01 0.25494694 MODEL
# theta[41] 2.292379e-01 0.43167110 MODEL
# theta[42] 8.118829e-04 0.37379647 MODEL
# theta[43] 1.646219e-02 0.46599422 MODEL
# theta[44] 1.012640e-02 0.12507892 MODEL
# theta[45] 1.552983e-04 0.18500001 MODEL
# theta[46] 2.815567e-05 0.14182109 MODEL
# theta[47] 2.764758e-03 0.10616795 MODEL
# theta[48] 5.520110e-03 0.17915367 MODEL

# %%
options(repr.plot.width = 25, repr.plot.height = 33)
fit_vis_df %>% 
    ggplot(aes(x = reorder(CovidenceID, PointEst), y = PointEst, ymin = Lower, ymax = Upper, colour = Type)) +
        geom_pointrange(position = position_dodge(width = 0.6)) + 
        coord_flip() + 
        theme(text = element_text(size = 22), legend.position = "top", legend.justification = "left") +
        xlab("Study") + ylab("Effect Size") + ylim(0,1) + 
        facet_wrap(vars(Scenario), scales = "free", ncol = 4)

if(save_output){
    ggsave(file.path(visuals_output_dir, paste0("ModelFitPerStudy", ".png")), width = 25, height = 33, unit = "in", dpi = 800, limitsize = FALSE)
}
# Out:
# plot without title

# %% [markdown]
# # Scenario Summary
# Here we generate a visual showing the pooled estimate for each scenario.

# %%
input_data %>% names
ref_region = input_data$ref_region
non_ref_region = ifelse(ref_region == "Asia", "Americas", "Asia")
ref_serotype_exposure = input_data$ref_serotype_exposure
ref_scenario = input_data$ref_scenario


#Name of what cases are considered severe
severe_name = "Severe"
if(sev_class_type == "1997type"){
    severe_name = "DHF/DSS"
}else if(sev_class_type == "2009type"){
    severe_name = "SD"
}else{
    severe_name = "Hospitalised"
}
# Out:
# [1] "data_list"             "outcome_df"            "study_df"
# [4] "scenario_df"           "char_mat_guide"        "ref_region"
# [7] "ref_serotype_exposure" "ref_scenario"

# %%
non_ref_seroprior = input_data$char_mat_guide %>% filter(CharMatIndex >0) %>% pull(SeroPriorExp) %>% as.character
scenario_labels = c(ref_scenario, 
                    paste0(ref_region, "-", non_ref_seroprior),
                    paste0(non_ref_region, "-", c(ref_serotype_exposure, non_ref_seroprior))
                   )

# %%
#Get the scenario estimates, which are given as p from the model
p_estimates = summary(model_results, pars = "p")$summary %>% data.frame
p_estimates = p_estimates %>% select(mean, X2.5., X97.5.) %>% 
    rename(PointEst = mean, Lower = X2.5., Upper = X97.5.) %>% mutate(Scenario = scenario_labels)

scenario_df = input_data$scenario_df %>% left_join(het_results %>% select(Scenario, I2_est), by = "Scenario")
scenario_vis_df = scenario_df %>% left_join(p_estimates, by = "Scenario") %>% 
                    filter(!is.na(CharMatIndex)) %>% 
                    mutate(DispVal = sprintf("%.2f%% [%.2f to %.2f%%]", 100*PointEst, 100*Lower, 100*Upper)) %>%
                    mutate(DispHet = ifelse(is.na(I2_est), "-", sprintf("%.2f%%", I2_est * 100))) %>% 
                    mutate(Pooled = ifelse(Inclusion == "Included", "Pooled", "Not Pooled"))
                    
scenario_vis_df
# Out:
#    SeroPriorExp    Region   Scenario                 NumStudies Severe
# 1  Unknown-DENV1   Americas Americas-Unknown-DENV1   7          7496
# 2  Unknown-DENV2   Americas Americas-Unknown-DENV2   6          1326
# 3  Unknown-DENV3   Americas Americas-Unknown-DENV3   3          1770
# 4  Unknown-DENV4   Americas Americas-Unknown-DENV4   2          2011
# 5  Primary-DENV1   Americas Americas-Primary-DENV1   0             0
# 6  Primary-DENV2   Americas Americas-Primary-DENV2   0             0
# 7  Primary-DENV3   Americas Americas-Primary-DENV3   0             0
# 8  Secondary-DENV1 Americas Americas-Secondary-DENV1 0             0
# 9  Secondary-DENV2 Americas Americas-Secondary-DENV2 0             0
# 10 Unknown-DENV1   Asia     Asia-Unknown-DENV1       5           182
# 11 Unknown-DENV2   Asia     Asia-Unknown-DENV2       7           299
# 12 Unknown-DENV3   Asia     Asia-Unknown-DENV3       5           336
# 13 Unknown-DENV4   Asia     Asia-Unknown-DENV4       3            15
# 14 Primary-DENV1   Asia     Asia-Primary-DENV1       2             4
# 15 Primary-DENV2   Asia     Asia-Primary-DENV2       2             1
# 16 Primary-DENV3   Asia     Asia-Primary-DENV3       2            22
# 17 Secondary-DENV1 Asia     Asia-Secondary-DENV1     2             4
# 18 Secondary-DENV2 Asia     Asia-Secondary-DENV2     2             7
#    NonSevere N     Inclusion ScenIndex CharMatIndex I2_est    PointEst
# 1  17413     24909 Included   1         1           0.9133893 0.12700327
# 2   2165      3491 Included   2         2           0.9609194 0.19570230
# 3   2555      4325 Included   3         3           0.9966949 0.25051171
# 4   6218      8229 Included   4         4           0.9993285 0.15210745
# 5      0         0 Excluded  -1         5                  NA 0.08007242
# 6      0         0 Excluded  -1         6                  NA 0.06677528
# 7      0         0 Excluded  -1         7                  NA 0.15761726
# 8      0         0 Excluded  -1         8                  NA 0.13423162
# 9      0         0 Excluded  -1        -1                  NA 0.13609469
# 10   369       551 Included   5         1           0.9706590 0.20178206
# 11   500       799 Included   6         2           0.9028899 0.29766647
# 12   783      1119 Included   7         3           0.8939260 0.36162584
# 13    23        38 Included   8         4           0.8262340 0.23507342
# 14    59        63 Included   9         5           0.4878834 0.11765776
# 15    19        20 Included  10         6           0.0000000 0.09812429
# 16    31        53 Included  11         7           0.9886912 0.22012959
# 17    47        51 Included  12         8           0.9075151 0.19115289
# 18    32        39 Included  13        -1           0.9367085 0.20431754
#    Lower       Upper     DispVal                  DispHet Pooled
# 1  0.033684200 0.3368358 12.70% [3.37 to 33.68%]  91.34%  Pooled
# 2  0.065445199 0.3832812 19.57% [6.54 to 38.33%]  96.09%  Pooled
# 3  0.075754151 0.4875047 25.05% [7.58 to 48.75%]  99.67%  Pooled
# 4  0.022976660 0.3991791 15.21% [2.30 to 39.92%]  99.93%  Pooled
# 5  0.005711458 0.3829137 8.01% [0.57 to 38.29%]   -       Not Pooled
# 6  0.002096509 0.3643483 6.68% [0.21 to 36.43%]   -       Not Pooled
# 7  0.003670771 0.6788601 15.76% [0.37 to 67.89%]  -       Not Pooled
# 8  0.005687083 0.5896893 13.42% [0.57 to 58.97%]  -       Not Pooled
# 9  0.023347442 0.3828973 13.61% [2.33 to 38.29%]  -       Not Pooled
# 10 0.056137849 0.4131982 20.18% [5.61 to 41.32%]  97.07%  Pooled
# 11 0.135303592 0.4999577 29.77% [13.53 to 50.00%] 90.29%  Pooled
# 12 0.219385275 0.5479855 36.16% [21.94 to 54.80%] 89.39%  Pooled
# 13 0.048660467 0.5403536 23.51% [4.87 to 54.04%]  82.62%  Pooled
# 14 0.013907574 0.4793418 11.77% [1.39 to 47.93%]  48.79%  Pooled
# 15 0.004632254 0.4612811 9.81% [0.46 to 46.13%]   0.00%   Pooled
# 16 0.007870779 0.7559181 22.01% [0.79 to 75.59%]  98.87%  Pooled
# 17 0.012987184 0.6784934 19.12% [1.30 to 67.85%]  90.75%  Pooled
# 18 0.058934031 0.4514398 20.43% [5.89 to 45.14%]  93.67%  Pooled

# %%
#Generate a forest plot specifically for this severity class
options(repr.plot.width = 15, repr.plot.height = 13)
scenario_plot = scenario_vis_df %>% arrange(Scenario) %>%
    forestplot(labeltext = c(Scenario, Pooled, NumStudies, N, Severe, DispVal, DispHet),
                mean = PointEst, lower = Lower, upper = Upper,
                xticks = seq(0, 1, by = 0.2), ci.vertices = TRUE, boxsize = 0.2,
                align = c("l", "l", "l", "r", "r"), graphwidth = unit(1.8, "in")
              ) |>
    fp_add_lines(h_2 = gpar(lty = 2)) |>
    fp_set_style(box = "royalblue", line = gpar(col = "darkblue"), summary = "royalblue",
                txt_gp = fpTxtGp(cex =1.2, ticks = gpar(cex = 1))) |>
    fp_add_header(
                    Scenario = "Scenario", 
                    Pooled = "Pooling?",
                    NumStudies = "# Studies",
                    N = "N", 
                    Severe = severe_name, 
                    DispVal = "Est. Proportion [95% CrI]",
                    DispHet = expression(I^{2})
    ) |> fp_decorate_graph(graph.pos = 7) |> fp_set_zebra_style("#EFEFEF")

if(save_output){
    save_plot(scenario_plot, file.path(visuals_output_dir, paste0("SubgroupForest_",  sev_class_type, ".png")), 15, 13, "in", 600)
}
scenario_plot
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Odds Ratios versus Reference
# Here we generate a visual of the odds ratios for each effect versus the reference class.

# %%
or_labels = c("Intercept", non_ref_seroprior, non_ref_region)
or_labels
# Out:
#  [1] "Intercept"       "Unknown-DENV1"   "Unknown-DENV2"   "Unknown-DENV3"
#  [5] "Unknown-DENV4"   "Primary-DENV1"   "Primary-DENV2"   "Primary-DENV3"
#  [9] "Secondary-DENV1" "Americas"

# %%
process_or_beta = function(par_name){
    beta_or_est  = summary(model_results, pars = c(par_name))$summary %>% data.frame %>%
                mutate(Label = or_labels) %>% select(Label, mean, X2.5., X97.5.) %>% 
                rename(PointEst = mean, Lower = X2.5., Upper = X97.5.)
    return(beta_or_est)
}
log_beta_or_est = process_or_beta("log_or_beta") %>% select(-Label) %>% rename(LogPointEst = PointEst, LogLower = Lower, LogUpper = Upper)
beta_or_est = process_or_beta("or_beta")

beta_or_est = cbind(beta_or_est, log_beta_or_est)

# %%
#We don't need the intercept
ref_seroexp_label = data.frame(Label = paste0("Versus ", ref_serotype_exposure), PointEst = NA, Lower = NA, Upper  = NA, LogPointEst = NA, LogLower = NA, LogUpper = NA, DispVal = NA, LogDispVal = NA)
ref_region_label = data.frame(Label = paste0("Versus ", ref_region), PointEst = NA, Lower = NA, Upper  = NA, LogPointEst = NA, LogLower = NA, LogUpper = NA, DispVal = NA, LogDispVal = NA)
beta_or_vis_df = beta_or_est %>% filter(Label != "Intercept") %>% 
                    mutate(DispVal = sprintf("%.2f [%.2f to %.2f]", PointEst, Lower, Upper)) %>% 
                    mutate(LogDispVal = sprintf("%.2f [%.2f to %.2f]", LogPointEst, LogLower, LogUpper))

or_seroexp_part = beta_or_vis_df %>% filter(Label != non_ref_region) %>% mutate(Label = paste0("     ", Label))
or_region_part = beta_or_vis_df %>% filter(Label == non_ref_region)%>% mutate(Label = paste0("     ", Label))

beta_or_vis_df = rbind(ref_seroexp_label, or_seroexp_part, ref_region_label, or_region_part)

#Add significance labels
beta_or_vis_df = beta_or_vis_df %>% mutate(DispVal = ifelse(((Lower > 1) | (Upper < 1)), paste0(DispVal, "*"), DispVal),
                                          LogDispVal = ifelse(((LogLower > 0) | (LogUpper < 0)), paste0(LogDispVal, "*"), LogDispVal))

# %%
beta_or_vis_df
# Out:
#             Label                  PointEst  Lower      Upper     LogPointEst
# 1           Versus Secondary-DENV2        NA         NA        NA           NA
# or_beta[2]       Unknown-DENV1     1.4022698 0.18856879  5.040312 -0.007758869
# or_beta[3]       Unknown-DENV2     2.3604776 0.39912470  7.684434  0.578324979
# or_beta[4]       Unknown-DENV3     3.1565351 0.60095655 10.055665  0.893543145
# or_beta[5]       Unknown-DENV4     1.7995792 0.17554301  7.044168  0.149866200
# or_beta[6]       Primary-DENV1     0.8313010 0.05002790  4.117996 -0.894829533
# or_beta[7]       Primary-DENV2     0.7020119 0.01922041  3.882411 -1.317105513
# or_beta[8]       Primary-DENV3     2.2564934 0.03738109 13.463056 -0.266452834
# or_beta[9]       Secondary-DENV1   1.6697004 0.05328647  9.217242 -0.360660427
# 11          Versus Asia                   NA         NA        NA           NA
# or_beta[10]      Americas          0.6495475 0.16441483  1.677298 -0.603664734
#             LogLower   LogUpper  DispVal              LogDispVal
# 1                   NA        NA NA                   NA
# or_beta[2]  -1.6682924 1.6174680 1.40 [0.19 to 5.04]  -0.01 [-1.67 to 1.62]
# or_beta[3]  -0.9184814 2.0391968 2.36 [0.40 to 7.68]  0.58 [-0.92 to 2.04]
# or_beta[4]  -0.5092327 2.3081361 3.16 [0.60 to 10.06] 0.89 [-0.51 to 2.31]
# or_beta[5]  -1.7398712 1.9522001 1.80 [0.18 to 7.04]  0.15 [-1.74 to 1.95]
# or_beta[6]  -2.9951744 1.4153664 0.83 [0.05 to 4.12]  -0.89 [-3.00 to 1.42]
# or_beta[7]  -3.9517824 1.3564563 0.70 [0.02 to 3.88]  -1.32 [-3.95 to 1.36]
# or_beta[8]  -3.2865904 2.5999493 2.26 [0.04 to 13.46] -0.27 [-3.29 to 2.60]
# or_beta[9]  -2.9320729 2.2210759 1.67 [0.05 to 9.22]  -0.36 [-2.93 to 2.22]
# 11                  NA        NA NA                   NA
# or_beta[10] -1.8053626 0.5171844 0.65 [0.16 to 1.68]  -0.60 [-1.81 to 0.52]

# %%
options(repr.plot.width = 10, repr.plot.height = 10)
or_versus_ref_plot = beta_or_vis_df %>%forestplot(labeltext = c(Label, DispVal), zero = 0,
                mean = LogPointEst, lower = LogLower, upper = LogUpper,
                xticks = seq(-5, 5, by = 1), ci.vertices = TRUE, boxsize = 0.2,
                align = c("l", "l"), graphwidth = unit(2.2, "in"), xlab = "Est. Log Odds Ratio [95% CrI]"
              ) |>
    fp_add_lines(h_2 = gpar(lty = 2)) |>
    fp_set_style(box = "royalblue", line = gpar(col = "darkblue"), summary = "royalblue", zero = "red",
                txt_gp = fpTxtGp(cex =1.2, ticks = gpar(cex = 1), xlab = gpar(cex = 1.2))) |>
    fp_add_header(
                    Label = "Variable", 
                    DispVal = "Est. Odds Ratio [95% CrI]"
                    #LogDispVal = "Est. Log Odds Ratio [95% CrI]"
    ) |> fp_set_zebra_style("#EFEFEF")

if(save_output){
    save_plot(or_versus_ref_plot, file.path(visuals_output_dir, paste0("ORvsRef_",  sev_class_type, ".png")), 10, 10, "in", 600)
}
or_versus_ref_plot
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Odds Ratio Pairwise Comparison (Serotype - Prior Exposure)
# Here, we generate a visual showing pairs of serotype-prior exposure effects and the odds ratio for severity between them (including the reference class and whether the difference was significant or not).

# %%
char_mat_guide = input_data$char_mat_guide
char_mat_guide
# Out:
#   SeroPriorExp    CharMatIndex
# 1 Unknown-DENV1    1
# 2 Unknown-DENV2    2
# 3 Unknown-DENV3    3
# 4 Unknown-DENV4    4
# 5 Primary-DENV1    5
# 6 Primary-DENV2    6
# 7 Primary-DENV3    7
# 8 Secondary-DENV1  8
# 9 Secondary-DENV2 -1

# %%
#We create a visual to show pairwise odds ratios (these would be in the sero_prior_or_ratios matrix)
sero_prior_mat = summary(model_results, pars = "sero_prior_or_ratios")$summary %>% data.frame %>%
                select(mean, X2.5., X97.5.) %>%
                rename(PointEst = mean, Lower = X2.5., Upper = X97.5.) %>%
                mutate(Name = rownames(.)) %>%
                separate(Name, sep = "\\[|,|\\]", into = c(NA, "ROW", "COL", NA)) %>% 
                mutate(ROW = as.numeric(ROW), COL = as.numeric(COL)) %>%
                filter(COL > ROW) %>% 
                left_join(char_mat_guide, by = c("ROW" = "CharMatIndex")) %>% #Join the indices based on the input char_mat_guide
                rename(RowScenario = SeroPriorExp) %>% 
                left_join(char_mat_guide, by = c("COL" = "CharMatIndex")) %>%
                rename(ColScenario = SeroPriorExp) %>% 
                select(-c(ROW, COL))

log_sero_prior_mat  = summary(model_results, pars = "log_sero_prior_or_ratios")$summary %>% data.frame %>%
                select(mean, X2.5., X97.5.) %>%
                rename(LogPointEst = mean, LogLower = X2.5., LogUpper = X97.5.) %>% mutate(Name = rownames(.)) %>%
                separate(Name, sep = "\\[|,|\\]", into = c(NA, "ROW", "COL", NA)) %>% 
                mutate(ROW = as.numeric(ROW), COL = as.numeric(COL)) %>%
                filter(COL > ROW) %>%
                select(-c(ROW, COL))
sero_prior_mat = cbind(sero_prior_mat, log_sero_prior_mat)

# %%
versus_ref_portion = beta_or_est %>% filter(!Label %in% c("Intercept", non_ref_region)) %>%
                        mutate(ColScenario = ref_serotype_exposure) %>% rename(RowScenario = Label)
#We add in the part of the matrix versus the reference class (the reference is the denominator of the OR)

sero_prior_mat_vis = sero_prior_mat %>% rbind(versus_ref_portion) %>% 
                    mutate(Significance = ifelse(((Lower > 1) | (Upper < 1)),"Significant", "Not Significant")) %>% #Check for significant OR   
                    arrange(desc(Significance), desc(PointEst)) %>% 
                    mutate(DispVal = sprintf("%.2f [%.2f to %.2f]", PointEst, Lower, Upper),
                          LogDispVal = sprintf("%.2f [%.2f to %.2f]", LogPointEst, LogLower, LogUpper))
sero_prior_mat_vis
# Out:
#                               PointEst   Lower       Upper      RowScenario
# log_sero_prior_or_ratios[3,6] 23.6824346 0.605663351 129.910210 Unknown-DENV3
# log_sero_prior_or_ratios[2,6] 17.2936243 0.421689820  96.959328 Unknown-DENV2
# log_sero_prior_or_ratios[4,6] 13.6337289 0.217358424  79.550703 Unknown-DENV4
# log_sero_prior_or_ratios[3,7] 11.6560017 0.167988659  75.871854 Unknown-DENV3
# log_sero_prior_or_ratios[3,5] 10.3997535 0.575992701  44.732498 Unknown-DENV3
# log_sero_prior_or_ratios[1,6] 10.3922989 0.201436762  58.192287 Unknown-DENV1
# log_sero_prior_or_ratios[2,7]  8.5808353 0.118190161  55.665155 Unknown-DENV2
# log_sero_prior_or_ratios[3,8]  8.5361294 0.241082370  46.468289 Unknown-DENV3
# log_sero_prior_or_ratios[2,5]  7.8144048 0.395238578  33.458276 Unknown-DENV2
# log_sero_prior_or_ratios[7,8]  7.0013736 0.025050635  42.180559 Primary-DENV3
# log_sero_prior_or_ratios[4,7]  6.6626907 0.060146789  43.723376 Unknown-DENV4
# log_sero_prior_or_ratios[5,6]  6.6274879 0.064037817  38.041081 Primary-DENV1
# log_sero_prior_or_ratios[2,8]  6.3937939 0.169479933  35.064111 Unknown-DENV2
# log_sero_prior_or_ratios[4,5]  6.0713458 0.193469448  30.162255 Unknown-DENV4
# log_sero_prior_or_ratios[1,7]  5.1396943 0.057217765  33.488062 Unknown-DENV1
# log_sero_prior_or_ratios[4,8]  4.9817404 0.082738492  28.786378 Unknown-DENV4
# log_sero_prior_or_ratios[1,5]  4.6904277 0.199454197  21.945658 Unknown-DENV1
# log_sero_prior_or_ratios[1,8]  3.8443507 0.085457087  21.288187 Unknown-DENV1
# log_sero_prior_or_ratios[5,7]  3.4323746 0.017811759  19.199758 Primary-DENV1
# or_beta[4]                     3.1565351 0.600956551  10.055665 Unknown-DENV3
# log_sero_prior_or_ratios[3,4]  3.0732598 0.438180012  11.326378 Unknown-DENV3
# log_sero_prior_or_ratios[5,8]  2.6504631 0.026491177  13.770562 Primary-DENV1
# log_sero_prior_or_ratios[6,7]  2.6188782 0.008061792  17.062296 Primary-DENV2
# or_beta[3]                     2.3604776 0.399124704   7.684434 Unknown-DENV2
# log_sero_prior_or_ratios[2,4]  2.2640220 0.297177927   8.735708 Unknown-DENV2
# or_beta[8]                     2.2564934 0.037381087  13.463056 Primary-DENV3
# log_sero_prior_or_ratios[6,8]  2.0740461 0.011195684  13.295660 Primary-DENV2
# or_beta[5]                     1.7995792 0.175543011   7.044168 Unknown-DENV4
# or_beta[9]                     1.6697004 0.053286469   9.217242 Secondary-DENV1
# or_beta[2]                     1.4022698 0.188568793   5.040312 Unknown-DENV1
# log_sero_prior_or_ratios[1,4]  1.3495108 0.138816197   5.635906 Unknown-DENV1
# log_sero_prior_or_ratios[2,3]  0.8401559 0.243493414   2.049652 Unknown-DENV2
# or_beta[6]                     0.8313010 0.050027902   4.117996 Primary-DENV1
# or_beta[7]                     0.7020119 0.019220413   3.882411 Primary-DENV2
# log_sero_prior_or_ratios[1,2]  0.6821436 0.151209616   1.931346 Unknown-DENV1
# log_sero_prior_or_ratios[1,3]  0.5041000 0.100236946   1.414023 Unknown-DENV1
#                               ColScenario     LogPointEst  LogLower   LogUpper
# log_sero_prior_or_ratios[3,6] Primary-DENV2    2.210648658 -0.5014310 4.8668435
# log_sero_prior_or_ratios[2,6] Primary-DENV2    1.895430493 -0.8634853 4.5742916
# log_sero_prior_or_ratios[4,6] Primary-DENV2    1.466971713 -1.5262084 4.3763944
# log_sero_prior_or_ratios[3,7] Primary-DENV3    1.159995979 -1.7838588 4.3290458
# log_sero_prior_or_ratios[3,5] Primary-DENV1    1.788372677 -0.5516604 3.8007001
# log_sero_prior_or_ratios[1,6] Primary-DENV2    1.309346644 -1.6022799 4.0637526
# log_sero_prior_or_ratios[2,7] Primary-DENV3    0.844777813 -2.1354604 4.0193543
# log_sero_prior_or_ratios[3,8] Secondary-DENV1  1.254203572 -1.4226166 3.8387701
# log_sero_prior_or_ratios[2,5] Primary-DENV1    1.473154512 -0.9282657 3.5102991
# log_sero_prior_or_ratios[7,8] Secondary-DENV1  0.094207593 -3.6868563 3.7419594
# log_sero_prior_or_ratios[4,7] Primary-DENV3    0.416319034 -2.8109673 3.7778829
# log_sero_prior_or_ratios[5,6] Primary-DENV2    0.422275981 -2.7482815 3.6386666
# log_sero_prior_or_ratios[2,8] Secondary-DENV1  0.938985407 -1.7750210 3.5571781
# log_sero_prior_or_ratios[4,5] Primary-DENV1    1.044695733 -1.6426357 3.4065913
# log_sero_prior_or_ratios[1,7] Primary-DENV3    0.258693965 -2.8608910 3.5111888
# log_sero_prior_or_ratios[4,8] Secondary-DENV1  0.510526628 -2.4920703 3.3599022
# log_sero_prior_or_ratios[1,5] Primary-DENV1    0.887070664 -1.6121707 3.0885693
# log_sero_prior_or_ratios[1,8] Secondary-DENV1  0.352901559 -2.4597409 3.0581523
# log_sero_prior_or_ratios[5,7] Primary-DENV3   -0.628376699 -4.0278964 2.9548977
# or_beta[4]                    Secondary-DENV2  0.893543145 -0.5092327 2.3081361
# log_sero_prior_or_ratios[3,4] Unknown-DENV4    0.743676944 -0.8251255 2.4271344
# log_sero_prior_or_ratios[5,8] Secondary-DENV1 -0.534169105 -3.6309435 2.6225330
# log_sero_prior_or_ratios[6,7] Primary-DENV3   -1.050652679 -4.8206194 2.8368711
# or_beta[3]                    Secondary-DENV2  0.578324979 -0.9184814 2.0391968
# log_sero_prior_or_ratios[2,4] Unknown-DENV4    0.428458779 -1.2134242 2.1674190
# or_beta[8]                    Secondary-DENV2 -0.266452834 -3.2865904 2.5999493
# log_sero_prior_or_ratios[6,8] Secondary-DENV1 -0.956445086 -4.4922270 2.5874377
# or_beta[5]                    Secondary-DENV2  0.149866200 -1.7398712 1.9522001
# or_beta[9]                    Secondary-DENV2 -0.360660427 -2.9320729 2.2210759
# or_beta[2]                    Secondary-DENV2 -0.007758869 -1.6682924 1.6174680
# log_sero_prior_or_ratios[1,4] Unknown-DENV4   -0.157625069 -1.9746045 1.7291579
# log_sero_prior_or_ratios[2,3] Unknown-DENV3   -0.315218165 -1.4126654 0.7176700
# or_beta[6]                    Secondary-DENV2 -0.894829533 -2.9951744 1.4153664
# or_beta[7]                    Secondary-DENV2 -1.317105513 -3.9517824 1.3564563
# log_sero_prior_or_ratios[1,2] Unknown-DENV2   -0.586083848 -1.8890882 0.6582170
# log_sero_prior_or_ratios[1,3] Unknown-DENV3   -0.901302013 -2.3002184 0.3464389
#                               Significance    DispVal
# log_sero_prior_or_ratios[3,6] Not Significant 23.68 [0.61 to 129.91]
# log_sero_prior_or_ratios[2,6] Not Significant 17.29 [0.42 to 96.96]
# log_sero_prior_or_ratios[4,6] Not Significant 13.63 [0.22 to 79.55]
# log_sero_prior_or_ratios[3,7] Not Significant 11.66 [0.17 to 75.87]
# log_sero_prior_or_ratios[3,5] Not Significant 10.40 [0.58 to 44.73]
# log_sero_prior_or_ratios[1,6] Not Significant 10.39 [0.20 to 58.19]
# log_sero_prior_or_ratios[2,7] Not Significant 8.58 [0.12 to 55.67]
# log_sero_prior_or_ratios[3,8] Not Significant 8.54 [0.24 to 46.47]
# log_sero_prior_or_ratios[2,5] Not Significant 7.81 [0.40 to 33.46]
# log_sero_prior_or_ratios[7,8] Not Significant 7.00 [0.03 to 42.18]
# log_sero_prior_or_ratios[4,7] Not Significant 6.66 [0.06 to 43.72]
# log_sero_prior_or_ratios[5,6] Not Significant 6.63 [0.06 to 38.04]
# log_sero_prior_or_ratios[2,8] Not Significant 6.39 [0.17 to 35.06]
# log_sero_prior_or_ratios[4,5] Not Significant 6.07 [0.19 to 30.16]
# log_sero_prior_or_ratios[1,7] Not Significant 5.14 [0.06 to 33.49]
# log_sero_prior_or_ratios[4,8] Not Significant 4.98 [0.08 to 28.79]
# log_sero_prior_or_ratios[1,5] Not Significant 4.69 [0.20 to 21.95]
# log_sero_prior_or_ratios[1,8] Not Significant 3.84 [0.09 to 21.29]
# log_sero_prior_or_ratios[5,7] Not Significant 3.43 [0.02 to 19.20]
# or_beta[4]                    Not Significant 3.16 [0.60 to 10.06]
# log_sero_prior_or_ratios[3,4] Not Significant 3.07 [0.44 to 11.33]
# log_sero_prior_or_ratios[5,8] Not Significant 2.65 [0.03 to 13.77]
# log_sero_prior_or_ratios[6,7] Not Significant 2.62 [0.01 to 17.06]
# or_beta[3]                    Not Significant 2.36 [0.40 to 7.68]
# log_sero_prior_or_ratios[2,4] Not Significant 2.26 [0.30 to 8.74]
# or_beta[8]                    Not Significant 2.26 [0.04 to 13.46]
# log_sero_prior_or_ratios[6,8] Not Significant 2.07 [0.01 to 13.30]
# or_beta[5]                    Not Significant 1.80 [0.18 to 7.04]
# or_beta[9]                    Not Significant 1.67 [0.05 to 9.22]
# or_beta[2]                    Not Significant 1.40 [0.19 to 5.04]
# log_sero_prior_or_ratios[1,4] Not Significant 1.35 [0.14 to 5.64]
# log_sero_prior_or_ratios[2,3] Not Significant 0.84 [0.24 to 2.05]
# or_beta[6]                    Not Significant 0.83 [0.05 to 4.12]
# or_beta[7]                    Not Significant 0.70 [0.02 to 3.88]
# log_sero_prior_or_ratios[1,2] Not Significant 0.68 [0.15 to 1.93]
# log_sero_prior_or_ratios[1,3] Not Significant 0.50 [0.10 to 1.41]
#                               LogDispVal
# log_sero_prior_or_ratios[3,6] 2.21 [-0.50 to 4.87]
# log_sero_prior_or_ratios[2,6] 1.90 [-0.86 to 4.57]
# log_sero_prior_or_ratios[4,6] 1.47 [-1.53 to 4.38]
# log_sero_prior_or_ratios[3,7] 1.16 [-1.78 to 4.33]
# log_sero_prior_or_ratios[3,5] 1.79 [-0.55 to 3.80]
# log_sero_prior_or_ratios[1,6] 1.31 [-1.60 to 4.06]
# log_sero_prior_or_ratios[2,7] 0.84 [-2.14 to 4.02]
# log_sero_prior_or_ratios[3,8] 1.25 [-1.42 to 3.84]
# log_sero_prior_or_ratios[2,5] 1.47 [-0.93 to 3.51]
# log_sero_prior_or_ratios[7,8] 0.09 [-3.69 to 3.74]
# log_sero_prior_or_ratios[4,7] 0.42 [-2.81 to 3.78]
# log_sero_prior_or_ratios[5,6] 0.42 [-2.75 to 3.64]
# log_sero_prior_or_ratios[2,8] 0.94 [-1.78 to 3.56]
# log_sero_prior_or_ratios[4,5] 1.04 [-1.64 to 3.41]
# log_sero_prior_or_ratios[1,7] 0.26 [-2.86 to 3.51]
# log_sero_prior_or_ratios[4,8] 0.51 [-2.49 to 3.36]
# log_sero_prior_or_ratios[1,5] 0.89 [-1.61 to 3.09]
# log_sero_prior_or_ratios[1,8] 0.35 [-2.46 to 3.06]
# log_sero_prior_or_ratios[5,7] -0.63 [-4.03 to 2.95]
# or_beta[4]                    0.89 [-0.51 to 2.31]
# log_sero_prior_or_ratios[3,4] 0.74 [-0.83 to 2.43]
# log_sero_prior_or_ratios[5,8] -0.53 [-3.63 to 2.62]
# log_sero_prior_or_ratios[6,7] -1.05 [-4.82 to 2.84]
# or_beta[3]                    0.58 [-0.92 to 2.04]
# log_sero_prior_or_ratios[2,4] 0.43 [-1.21 to 2.17]
# or_beta[8]                    -0.27 [-3.29 to 2.60]
# log_sero_prior_or_ratios[6,8] -0.96 [-4.49 to 2.59]
# or_beta[5]                    0.15 [-1.74 to 1.95]
# or_beta[9]                    -0.36 [-2.93 to 2.22]
# or_beta[2]                    -0.01 [-1.67 to 1.62]
# log_sero_prior_or_ratios[1,4] -0.16 [-1.97 to 1.73]
# log_sero_prior_or_ratios[2,3] -0.32 [-1.41 to 0.72]
# or_beta[6]                    -0.89 [-3.00 to 1.42]
# or_beta[7]                    -1.32 [-3.95 to 1.36]
# log_sero_prior_or_ratios[1,2] -0.59 [-1.89 to 0.66]
# log_sero_prior_or_ratios[1,3] -0.90 [-2.30 to 0.35]

# %%
options(repr.plot.width = 13, repr.plot.height = 18)

axis_lim = 5
sero_prior_comp_plot = sero_prior_mat_vis %>%
                forestplot(labeltext = c(RowScenario, ColScenario, DispVal, Significance), zero = 0,
                mean = LogPointEst, lower = LogLower, upper = LogUpper, clip = c(-axis_lim, axis_lim),
                xticks = seq(-axis_lim, axis_lim, by = as.integer(axis_lim/5)), boxsize = 0.2,
                align = c("l", "l", "r", "r"), graphwidth = unit(2, "in"), ci.vertices.height = 0.2, xlab = "Est. Log Odds Ratio [95% CrI]"
              ) |>
    fp_add_lines(h_2 = gpar(lty = 2)) |>
    fp_set_style(box = "royalblue", line = gpar(col = "darkblue"), zero = "red", summary = "royalblue",
                txt_gp = fpTxtGp(cex =1.2, ticks = gpar(cex = 1), xlab = gpar(cex = 1.2))) |>
    fp_add_header(
                    RowScenario = "Numerator", 
                    ColScenario = "Denominator", 
                    DispVal = "Est. Odds Ratio [95% CrI]",
                    #LogDispVal = "Est. Log Odds Ratio [95% CrI]",
                    Significance = "Significance"
    ) |> fp_set_zebra_style("#EFEFEF") |> fp_decorate_graph(graph.pos = 4)
if(save_output){
    save_plot(sero_prior_comp_plot, file.path(visuals_output_dir, paste0("SeroPriorComp_",  sev_class_type, ".png")), 15, 18, "in", 600)
}
sero_prior_comp_plot
# Out:
# png
#   2
# plot without title

# %%
#Same plot as abive but without the unknowns
options(repr.plot.width = 13, repr.plot.height = 12)
axis_lim = 5
sero_prior_comp_plot_known = sero_prior_mat_vis %>% filter(!(str_detect(RowScenario, "Unknown") | str_detect(ColScenario, "Unknown"))) %>%
                forestplot(labeltext = c(RowScenario, ColScenario, DispVal, Significance), zero = 0, 
                clip = c(-axis_lim, axis_lim), 
                mean = LogPointEst, lower = LogLower, upper = LogUpper,
                xticks = seq(-axis_lim, axis_lim, by = as.integer(axis_lim/5)), 
                ci.vertices = FALSE, boxsize = 0.2, ci.vertices.height = 0.2, 
                align = c("l", "l", "r", "r"), graphwidth = unit(2, "in"), xlab = "Est. Log Odds Ratio [95% CrI]"
              ) |>
    fp_add_lines(h_2 = gpar(lty = 2)) |>
    fp_set_style(box = "royalblue", line = gpar(col = "darkblue"), zero = "red", summary = "royalblue",
                txt_gp = fpTxtGp(cex =1.2, ticks = gpar(cex = 1.1), xlab = gpar(cex = 1.3))) |>
    fp_add_header(
                    RowScenario = "Numerator", 
                    ColScenario = "Denominator", 
                    DispVal = "Est. Odds Ratio [95% CrI]",
                    #LogDispVal = "Est. Log Odds Ratio [95% CrI]",
                    Significance = "Significance"
    ) |> fp_set_zebra_style("#EFEFEF") |> fp_decorate_graph(graph.pos = 5)
if(save_output){
    save_plot(sero_prior_comp_plot_known, file.path(visuals_output_dir, paste0("SeroPriorComp_Known_",  sev_class_type, ".png")), 13, 12, "in", 600)
}
sero_prior_comp_plot_known
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Scenario Forests
# In this section, we make individual forest plots for each of the scenarios where we pool data.

# %%
theta_df = summary(model_results, pars = "theta")$summary %>% data.frame %>% 
                select(mean, X2.5., X97.5.) %>% rename(PointEst = mean, Lower = X2.5., Upper = X97.5.)

outcome_ests = outcome_df %>% cbind(theta_df) %>% 
                mutate(DispVal = sprintf("%.2f%% [%.2f to %.2f%%]", 100*PointEst, 100*Lower, 100*Upper))

outcome_ests
# Out:
#           ID   CovidenceID              Region   Serotype PriorExp  NonSevere
# theta[1]  0315 #66490 - Fiora 2024      Americas DENV1    Unknown      25
# theta[2]  0297 #1923 - Hanna 1998       Asia     DENV2    Unknown       6
# theta[3]  0024 #1924 - Hanna 2001       Asia     DENV3    Unknown     397
# theta[4]  0333 #66352 - Rahim 2023      Asia     DENV1    Unknown      22
# theta[5]  0333 #66352 - Rahim 2023      Asia     DENV2    Unknown      23
# theta[6]  0333 #66352 - Rahim 2023      Asia     DENV3    Unknown     262
# theta[7]  0139 #2880 - Ly 2022          Americas DENV1    Unknown      13
# theta[8]  0139 #2880 - Ly 2022          Americas DENV2    Unknown      11
# theta[9]  0021 #661 - Burattini 2016    Americas DENV1    Unknown    5422
# theta[10] 0021 #661 - Burattini 2016    Americas DENV2    Unknown     902
# theta[11] 0021 #661 - Burattini 2016    Americas DENV3    Unknown    1546
# theta[12] 0021 #661 - Burattini 2016    Americas DENV4    Unknown    2856
# theta[13] 0314 #66248 - Estofolete 2023 Americas DENV1    Unknown     385
# theta[14] 0314 #66248 - Estofolete 2023 Americas DENV2    Unknown      49
# theta[15] 0115 #365 - Aubry 2019        Asia     DENV1    Unknown     212
# theta[16] 0115 #365 - Aubry 2019        Asia     DENV2    Unknown      98
# theta[17] 0292 #1695 - GomezDantes 1988 Americas DENV1    Unknown      44
# theta[18] 0313 #66187 - AlBalushi 2023  Asia     DENV2    Unknown      76
# theta[19] 0336 #66690 - Burgos 2025     Americas DENV1    Unknown     188
# theta[20] 0336 #66690 - Burgos 2025     Americas DENV2    Unknown     221
# theta[21] 0263 #735 - Capeding 2010     Asia     DENV3    Primary      14
# theta[22] 0061 #4191 - Santiago 2019    Americas DENV2    Unknown     154
# theta[23] 0061 #4191 - Santiago 2019    Americas DENV3    Unknown     146
# theta[24] 0335 #66614 - Rodriguez 2024  Americas DENV1    Unknown   11336
# theta[25] 0335 #66614 - Rodriguez 2024  Americas DENV2    Unknown     828
# theta[26] 0335 #66614 - Rodriguez 2024  Americas DENV3    Unknown     863
# theta[27] 0335 #66614 - Rodriguez 2024  Americas DENV4    Unknown    3362
# theta[28] 0165 #4095 - Rouers 2021      Asia     DENV1    Primary      12
# theta[29] 0165 #4095 - Rouers 2021      Asia     DENV2    Primary       9
# theta[30] 0165 #4095 - Rouers 2021      Asia     DENV1    Secondary     4
# theta[31] 0165 #4095 - Rouers 2021      Asia     DENV2    Secondary     7
# theta[32] 0105 #5345 - Yung 2015        Asia     DENV1    Unknown      37
# theta[33] 0105 #5345 - Yung 2015        Asia     DENV2    Unknown     156
# theta[34] 0105 #5345 - Yung 2015        Asia     DENV3    Unknown      43
# theta[35] 0104 #4127 - Sabchareon 2012  Asia     DENV1    Unknown      69
# theta[36] 0104 #4127 - Sabchareon 2012  Asia     DENV2    Unknown      58
# theta[37] 0104 #4127 - Sabchareon 2012  Asia     DENV3    Unknown      32
# theta[38] 0104 #4127 - Sabchareon 2012  Asia     DENV4    Unknown      11
# theta[39] 0296 #4158 - Salje 2018       Asia     DENV1    Unknown      29
# theta[40] 0296 #4158 - Salje 2018       Asia     DENV2    Unknown      83
# theta[41] 0296 #4158 - Salje 2018       Asia     DENV3    Unknown      49
# theta[42] 0296 #4158 - Salje 2018       Asia     DENV4    Unknown       6
# theta[43] 0289 #5457 - Mammen 2008      Asia     DENV4    Unknown       6
# theta[44] 0184 #1385 - Duyen 2011       Asia     DENV1    Primary      47
# theta[45] 0184 #1385 - Duyen 2011       Asia     DENV2    Primary      10
# theta[46] 0184 #1385 - Duyen 2011       Asia     DENV3    Primary      17
# theta[47] 0184 #1385 - Duyen 2011       Asia     DENV1    Secondary    43
# theta[48] 0184 #1385 - Duyen 2011       Asia     DENV2    Secondary    25
#           Severe N     SeroPriorExp    Scenario               RowIndex ColIndex
# theta[1]     0      25 Unknown-DENV1   Americas-Unknown-DENV1  1        1
# theta[2]     0       6 Unknown-DENV2   Asia-Unknown-DENV2      2        2
# theta[3]   101     498 Unknown-DENV3   Asia-Unknown-DENV3      3        3
# theta[4]    18      40 Unknown-DENV1   Asia-Unknown-DENV1      4        1
# theta[5]    29      52 Unknown-DENV2   Asia-Unknown-DENV2      4        2
# theta[6]   141     403 Unknown-DENV3   Asia-Unknown-DENV3      4        3
# theta[7]     0      13 Unknown-DENV1   Americas-Unknown-DENV1  5        1
# theta[8]     2      13 Unknown-DENV2   Americas-Unknown-DENV2  5        2
# theta[9]   708    6130 Unknown-DENV1   Americas-Unknown-DENV1  6        1
# theta[10]  309    1211 Unknown-DENV2   Americas-Unknown-DENV2  6        2
# theta[11]  313    1859 Unknown-DENV3   Americas-Unknown-DENV3  6        3
# theta[12]  267    3123 Unknown-DENV4   Americas-Unknown-DENV4  6        4
# theta[13]   46     431 Unknown-DENV1   Americas-Unknown-DENV1  7        1
# theta[14]   16      65 Unknown-DENV2   Americas-Unknown-DENV2  7        2
# theta[15]   13     225 Unknown-DENV1   Asia-Unknown-DENV1      8        1
# theta[16]    8     106 Unknown-DENV2   Asia-Unknown-DENV2      8        2
# theta[17]    0      44 Unknown-DENV1   Americas-Unknown-DENV1  9        1
# theta[18]   93     169 Unknown-DENV2   Asia-Unknown-DENV2     10        2
# theta[19]    6     194 Unknown-DENV1   Americas-Unknown-DENV1 11        1
# theta[20]    5     226 Unknown-DENV2   Americas-Unknown-DENV2 11        2
# theta[21]   22      36 Primary-DENV3   Asia-Primary-DENV3     12        7
# theta[22]  158     312 Unknown-DENV2   Americas-Unknown-DENV2 13        2
# theta[23]  114     260 Unknown-DENV3   Americas-Unknown-DENV3 13        3
# theta[24] 6736   18072 Unknown-DENV1   Americas-Unknown-DENV1 14        1
# theta[25]  836    1664 Unknown-DENV2   Americas-Unknown-DENV2 14        2
# theta[26] 1343    2206 Unknown-DENV3   Americas-Unknown-DENV3 14        3
# theta[27] 1744    5106 Unknown-DENV4   Americas-Unknown-DENV4 14        4
# theta[28]    2      14 Primary-DENV1   Asia-Primary-DENV1     15        5
# theta[29]    1      10 Primary-DENV2   Asia-Primary-DENV2     15        6
# theta[30]    3       7 Secondary-DENV1 Asia-Secondary-DENV1   15        9
# theta[31]    6      13 Secondary-DENV2 Asia-Secondary-DENV2   15       10
# theta[32]   66     103 Unknown-DENV1   Asia-Unknown-DENV1     16        1
# theta[33]  112     268 Unknown-DENV2   Asia-Unknown-DENV2     16        2
# theta[34]   37      80 Unknown-DENV3   Asia-Unknown-DENV3     16        3
# theta[35]   75     144 Unknown-DENV1   Asia-Unknown-DENV1     17        1
# theta[36]   40      98 Unknown-DENV2   Asia-Unknown-DENV2     17        2
# theta[37]   34      66 Unknown-DENV3   Asia-Unknown-DENV3     17        3
# theta[38]   14      25 Unknown-DENV4   Asia-Unknown-DENV4     17        4
# theta[39]   10      39 Unknown-DENV1   Asia-Unknown-DENV1     18        1
# theta[40]   17     100 Unknown-DENV2   Asia-Unknown-DENV2     18        2
# theta[41]   23      72 Unknown-DENV3   Asia-Unknown-DENV3     18        3
# theta[42]    0       6 Unknown-DENV4   Asia-Unknown-DENV4     18        4
# theta[43]    1       7 Unknown-DENV4   Asia-Unknown-DENV4     19        4
# theta[44]    2      49 Primary-DENV1   Asia-Primary-DENV1     20        5
# theta[45]    0      10 Primary-DENV2   Asia-Primary-DENV2     20        6
# theta[46]    0      17 Primary-DENV3   Asia-Primary-DENV3     20        7
# theta[47]    1      44 Secondary-DENV1 Asia-Secondary-DENV1   20        9
# theta[48]    1      26 Secondary-DENV2 Asia-Secondary-DENV2   20       10
#           RegIndex PointEst   Lower        Upper      DispVal
# theta[1]  1        0.02612863 2.823631e-04 0.10028781 2.61% [0.03 to 10.03%]
# theta[2]  2        0.13317348 6.255593e-03 0.38743048 13.32% [0.63 to 38.74%]
# theta[3]  2        0.20710489 1.726360e-01 0.24369261 20.71% [17.26 to 24.37%]
# theta[4]  2        0.43966683 2.945494e-01 0.59065419 43.97% [29.45 to 59.07%]
# theta[5]  2        0.54120306 4.103688e-01 0.67072354 54.12% [41.04 to 67.07%]
# theta[6]  2        0.35087639 3.057205e-01 0.39749218 35.09% [30.57 to 39.75%]
# theta[7]  1        0.04136976 5.439450e-04 0.15731340 4.14% [0.05 to 15.73%]
# theta[8]  1        0.15353216 2.981922e-02 0.36143350 15.35% [2.98 to 36.14%]
# theta[9]  1        0.11546664 1.075596e-01 0.12365125 11.55% [10.76 to 12.37%]
# theta[10] 1        0.25473004 2.308063e-01 0.27987756 25.47% [23.08 to 27.99%]
# theta[11] 1        0.16874732 1.519768e-01 0.18615828 16.87% [15.20 to 18.62%]
# theta[12] 1        0.08566612 7.612318e-02 0.09569888 8.57% [7.61 to 9.57%]
# theta[13] 1        0.10685597 7.928134e-02 0.13716286 10.69% [7.93 to 13.72%]
# theta[14] 1        0.24291893 1.497708e-01 0.35389290 24.29% [14.98 to 35.39%]
# theta[15] 2        0.06052458 3.347466e-02 0.09565510 6.05% [3.35 to 9.57%]
# theta[16] 2        0.08575971 4.099107e-02 0.14532584 8.58% [4.10 to 14.53%]
# theta[17] 1        0.01797670 2.552430e-04 0.06608851 1.80% [0.03 to 6.61%]
# theta[18] 2        0.54557334 4.698912e-01 0.61833594 54.56% [46.99 to 61.83%]
# theta[19] 1        0.03196993 1.258688e-02 0.05969167 3.20% [1.26 to 5.97%]
# theta[20] 1        0.02735293 1.031497e-02 0.05240207 2.74% [1.03 to 5.24%]
# theta[21] 2        0.59956265 4.371328e-01 0.75226565 59.96% [43.71 to 75.23%]
# theta[22] 1        0.50412282 4.489453e-01 0.55854807 50.41% [44.89 to 55.85%]
# theta[23] 1        0.43690317 3.780299e-01 0.49825800 43.69% [37.80 to 49.83%]
# theta[24] 1        0.37268042 3.655998e-01 0.37977229 37.27% [36.56 to 37.98%]
# theta[25] 1        0.50223250 4.781912e-01 0.52631417 50.22% [47.82 to 52.63%]
# theta[26] 1        0.60836140 5.880266e-01 0.62869403 60.84% [58.80 to 62.87%]
# theta[27] 1        0.34142260 3.283820e-01 0.35452526 34.14% [32.84 to 35.45%]
# theta[28] 2        0.11896712 2.234688e-02 0.31484489 11.90% [2.23 to 31.48%]
# theta[29] 2        0.08886347 5.924014e-03 0.29377925 8.89% [0.59 to 29.38%]
# theta[30] 2        0.36193328 7.755558e-02 0.71626809 36.19% [7.76 to 71.63%]
# theta[31] 2        0.41617877 1.767611e-01 0.67925689 41.62% [17.68 to 67.93%]
# theta[32] 2        0.63201297 5.375645e-01 0.72386092 63.20% [53.76 to 72.39%]
# theta[33] 2        0.41725714 3.590344e-01 0.47679596 41.73% [35.90 to 47.68%]
# theta[34] 2        0.45108807 3.511318e-01 0.55506525 45.11% [35.11 to 55.51%]
# theta[35] 2        0.51652351 4.343528e-01 0.59753954 51.65% [43.44 to 59.75%]
# theta[36] 2        0.40645588 3.135967e-01 0.50245365 40.65% [31.36 to 50.25%]
# theta[37] 2        0.49187887 3.778520e-01 0.60855319 49.19% [37.79 to 60.86%]
# theta[38] 2        0.52908321 3.312155e-01 0.71723058 52.91% [33.12 to 71.72%]
# theta[39] 2        0.24983830 1.333390e-01 0.39113375 24.98% [13.33 to 39.11%]
# theta[40] 2        0.17586337 1.091302e-01 0.25494694 17.59% [10.91 to 25.49%]
# theta[41] 2        0.32470646 2.292379e-01 0.43167110 32.47% [22.92 to 43.17%]
# theta[42] 2        0.10440421 8.118829e-04 0.37379647 10.44% [0.08 to 37.38%]
# theta[43] 2        0.17719467 1.646219e-02 0.46599422 17.72% [1.65 to 46.60%]
# theta[44] 2        0.05254768 1.012640e-02 0.12507892 5.25% [1.01 to 12.51%]
# theta[45] 2        0.04391397 1.552983e-04 0.18500001 4.39% [0.02 to 18.50%]
# theta[46] 2        0.02888216 2.815567e-05 0.14182109 2.89% [0.00 to 14.18%]
# theta[47] 2        0.03573660 2.764758e-03 0.10616795 3.57% [0.28 to 10.62%]
# theta[48] 2        0.06272424 5.520110e-03 0.17915367 6.27% [0.55 to 17.92%]

# %%
inc_scenarios = scenario_vis_df %>% filter(Inclusion != "Excluded")

for(i in 1:nrow(inc_scenarios)){
    curr_row = inc_scenarios[i, ]
    curr_scen = curr_row$Scenario
    curr_scen_outcomes = outcome_ests %>% filter(Scenario == curr_scen)
    options(repr.plot.width = 13, repr.plot.height = nrow(curr_scen_outcomes))
    curr_scenario_plot = curr_scen_outcomes %>%
                    forestplot(labeltext = c(CovidenceID, Scenario, N, Severe, DispVal),
                    clip = c(-axis_lim, axis_lim), 
                    mean = PointEst, lower = Lower, upper = Upper,
                    xticks = seq(0, 1, by = 0.2), 
                    ci.vertices = FALSE, boxsize = 0.2, ci.vertices.height = 0.2, 
                    align = c("l", "l", "r", "r", "r"), graphwidth = unit(2, "in")
                  ) |>
        fp_add_lines(h_2 = gpar(lty = 2)) |>
        fp_set_style(box = "royalblue", line = gpar(col = "darkblue"), summary = "royalblue",
                    txt_gp = fpTxtGp(cex =1.2, ticks = gpar(cex = 1))) |>
        fp_add_header(
                        CovidenceID = "CovidenceID", 
                        Scenario = "Scenario", 
                        N = "N",
                        Severe = "Severe",
                        DispVal = "Est. Proportion [95% CrI]"
        ) |>  
        fp_append_row(
                mean = curr_row %>% pull(PointEst),
                lower = curr_row %>% pull(Lower),
                upper = curr_row %>% pull(Upper),
                CovidenceID = "Summary",
                DispVal = curr_row %>% pull(DispVal),
                is.summary = TRUE
        ) |>
        fp_set_zebra_style("#EFEFEF") |> fp_decorate_graph(graph.pos = 6)
    
    if(save_output){
        save_plot(curr_scenario_plot, file.path(subgroup_forests_dir, paste0("Forest_", curr_scen, ".png")), 13, nrow(curr_scen_outcomes), "in", 600)
    }
}

# %%
# intercept_est = rstan::extract(model_results, pars = "intercept")$intercept
# nat_scale_intercept = intercept_est %>% inv_logit

# coeffs_est = rstan::extract(model_results, pars = "coeffs")$coeffs
# reg_effects_est = coeffs_est[,11]

# intercept_reg = intercept_est + reg_effects_est
# nat_scale_intercept_reg = intercept_reg %>% inv_logit

# mean(nat_scale_intercept_reg)

# quantile(nat_scale_intercept_reg, probs = c(0.025, 0.975))

# coeffs_est

# %%
## Old versus New Prior
# #Old prior, standard normal on natural scale(limited between 0 and 1). We can just do acceptance rejection sampling
# num_samples = 50000
# counter = 1
# builder = array(-1, dim = num_samples)
# while(TRUE){
#     curr_sample = rnorm(n = 1, mean = 0, sd = 1)
#     if(curr_sample >= 0 & curr_sample <= 1){
#         builder[counter] = curr_sample
#         counter = counter + 1    
#     }
#     if(counter == (num_samples + 1)){break}
# }


# options(repr.plot.width = 16, repr.plot.height = 8)
# new_prior_draws = rnorm(n = num_samples, mean = 0, sd = 2)
# prior_vis_df = rbind(data.frame(Value = builder, Type = "Old", Scale = "Natural"),
#                      data.frame(Value = logit(builder), Type = "Old", Scale = "Logit"),
#                      data.frame(Value = inv_logit(new_prior_draws), Type = "New", Scale = "Natural"),
#                      data.frame(Value = new_prior_draws, Type = "New", Scale = "Logit")
#                     )
# #data.frame(Old_Nat = builder, Old_Logit = logit(builder), New_Nat = inv_logit(new_prior_draws), New_Logit = new_prior_draws)
# prior_vis_df %>%
#     ggplot(aes(x = Value, colour = Type)) + 
#         geom_density(linewidth = 1) + 
#         facet_wrap(vars(Scale), scales = "free") + 
#         theme(text = element_text(size = 18))

# if(save_output){
#     ggsave(file.path(visuals_output_dir, paste0("NewOldPriorCompare",  sev_class_type, ".png")),
#            width = 16, height = 8, unit = "in", dpi = 800, limitsize = FALSE)
# }
